# %% [markdown]
# Here we look to see if there is any natural clustering in the data.
#
# To do so, we do the following:
# - k-means
# - PCA
# - GMM
# - Fisher LDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import pywt
import csv
import glob
import os
import glob
import tqdm
import datetime

# load data
X = np.load("data_X.npy")
y = np.load("data_y.npy")

# %%
is_zero = np.sum(X, axis = 1) == 0
is_small = np.sum(X, axis = 1) < 10
is_smallish = np.sum(X, axis = 1) < 50

# %% [markdown]
# ### pca

# %%
# first fit PCA
pca = PCA(n_components=5)
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=5, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
# then plot some information
projected = pca.components_ @ X.T
plt.scatter(projected[0,:], projected[1,:], c=y)
plt.title("Projection onto top 2 PCA components")
plt.show()

# %%
plt.figure(figsize=(19,4))
n_comp = 5
for i in range(n_comp):
    plt.subplot(n_comp, 1, i+1)
    plt.plot(pca.components_[i, :])

plt.figure(figsize=(18, 4))
plt.subplot(1,2,1)
plt.plot(pca.explained_variance_)
plt.xticks(range(n_comp))
plt.title('Explained Variance')

plt.subplot(1,2,2)
plt.scatter(proj_data[0,:], proj_data[1,:])
plt.title('PCA Scatter')
plt.show()

# %% [markdown]
# ### fisher lda

# %% [markdown]
# ### k-means

# %% [markdown]
# ### gmm
